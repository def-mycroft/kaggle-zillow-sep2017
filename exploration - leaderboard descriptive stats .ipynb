# %%
import pandas as pd
import numpy as np
import os
import pickle_funcs as pk
import helpers
from matplotlib import pyplot
cwd = os.getcwd()[:-9]
out_path = "C:/Users/dasen/Google Drive/SYNC TO PC/"
downloads = "C:/Users/dasen/Downloads/"

# %% [markdown]
# # Description
#
# Exploration and setup of data for [kaggle project.](https://www.kaggle.com/c/zillow-prize-1/data)

# %% [markdown]
# # Look at Leaderboard Statistics

# %%
# view leaderboard summary stats
pd.read_csv(out_path + 'DATA-998 - 9-16-2017 - leaderboard.csv')['Score'].describe()
# Out:
# count    1.263500e+04
# mean     5.213752e+09
# std      5.389340e+11
# min      6.390940e-02
# 25%      6.441600e-02
# 50%      6.463630e-02
# 75%      6.506855e-02
# max      6.033603e+13
# Name: Score, dtype: float64

# %%
# create distribution of leaderboard scores
scores = pd.read_csv(out_path + 'DATA-998 - 9-16-2017 - leaderboard.csv')
sl = scores[scores.Score < np.percentile(scores.Score, 75)]['Score']

sl.plot(
    kind = 'density',
    xticks = np.linspace(sl.min(), sl.max(), num=10),
    figsize = (20, 10)
)
pyplot.show()
